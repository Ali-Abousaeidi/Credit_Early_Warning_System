# %% [markdown]
# # Features and Model
#
# Showcase notebook for target prevalence, behavioural trend features, model metrics, and watchlist lead time. Production logic lives in `src/`; this notebook reads generated report artifacts after running `python -m src.pipeline`.

# %%
import json
from pathlib import Path

for name in ['target_summary', 'feature_summary', 'model_metrics', 'watchlist_summary']:
    print(f'\n{name}')
    print(json.dumps(json.loads(Path(f'../reports/tables/{name}.json').read_text()), indent=2))

# %% [markdown]
# The lead-time and model diagnostic figures are saved under `reports/figures/`.
