# %% [markdown]
# # Panel EDA
#
# Showcase notebook for the synthetic account-month monitoring panel. Production logic lives in `src/`; this notebook reads generated report artifacts after running `python -m src.pipeline`.

# %%
import json
from pathlib import Path

summary = json.loads(Path('../reports/tables/transition_summary.json').read_text())
summary

# %% [markdown]
# The transition matrix and example trajectories are saved under `reports/figures/`.
